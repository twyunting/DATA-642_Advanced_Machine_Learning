# %%
# Install the related libraries
# %matplotlib inline
import matplotlib as plt
import numpy as np
import random

# %% [markdown]
# # Lab 2 - Basic concepts in Machine Learning
#
# ## Exercise 1
# Write a Python program to reproduce the results of Example 3.1 page 74 and 75. Use different values of the noise variance and report your findings

# %%
def func1(noise):
  x1 = random.uniform(1, 10) # The random variables x1 and x2 are over the interval [0, 10]
  x2 = random.uniform(1, 10)
  a = np.array([0.25, -0.25, 0.25], dtype=object) # theta0, theta1, and theta2
  b = np.matrix([[x1], [x2], [1]], dtype=object)
  ans = (np.dot(a, b)) + noise
  return ans

# if noise = 2
print(func1(2))
# Out:
# [[3.8823391577588016]]

# %%
# if noise = 5
print(func1(5))
# Out:
# [[4.1262431442396466]]

# %%
c = random.uniform(1, 10)
print(c)
# Out:
# 3.889801768187924

# %%
# if noise = 1
a = np.array([0.25, -0.25, 0.25])
b = np.matrix("2;3;4")
ans = np.dot(a, b)
print(ans)
# Out:
# [[0.75]]
