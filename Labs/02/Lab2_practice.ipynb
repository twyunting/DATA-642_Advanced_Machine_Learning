# %% [markdown]
# # Lab 2 - Basic concepts in Machine Learning
#
# ## Exercise 1
# Write a Python program to reproduce the results of Example 3.1 page 74 and 75. Use different values of the noise variance and report your findings
#
# ## Install the Packages

# %%
# Install the related libraries
# %matplotlib inline
import matplotlib as plt
import numpy as np
import random
import math
from sklearn import datasets
import pandas as pd

# %%
n = 50 # 50 samples
theta = np.array([[0.25, -0.25, 0.25]]) # stated in the question, 2D array
sigma1 = math.sqrt(1) # variance is 1, so the sd is sqrt(var)
sigma2 = math.sqrt(10) # variance is 10
sigma3 = math.sqrt(100) # variance is 100
sigma4 = math.sqrt(1000) # variance is 1000
np.random.seed(10)

# %% [markdown]
# ## Creating the Simulated Data

# %%
X = np.zeros(shape = (3, n), dtype=np.float32)
X[0, :] = 10*np.random.rand(1, n) # uniform distribution over [0, 1), then * 10. So [0, 10)
X[1, :] = 10*np.random.rand(1, n)
X[2, :] = np.ones(shape = (1, n))
# print(X) # X is 2D array
y = np.dot(theta, X)
#print(y)
print(y)
# Out:
# [[ 1.19697845  0.06822893 -0.21864355  1.74412972  0.53598142 -1.5486601
#   -1.72390661  1.0105654  -1.39253005 -0.15758578  0.46997046  0.37640405
#   -1.07652424  0.05497718  2.1833479   0.8883608   1.85535556  0.21604037
#    1.717637    0.10186362  1.50646289 -0.46830535  0.39603472  0.3441062
#    0.48871505  1.22729158 -0.40537035 -0.37525582 -0.31924868  0.70882452
#    0.74911404  0.27045131  1.02703059  0.39255106 -0.27602988  0.93825071
#   -0.2226955   1.71651375 -1.02670465  0.40195024  0.43113482  1.56622261
#    0.58674119 -0.0549221   0.27986199  0.89899766 -1.45279753  1.3579067
#    0.2680971  -0.63695273]]

# %%
# Add noise term to the original points
y1 = y + sigma1*np.random.rand(y.shape[0], y.shape[1]) # return 1x50 array
y2 = y + sigma2*np.random.rand(y.shape[0], y.shape[1]) # return 1x50 array
y3 = y + sigma3*np.random.rand(y.shape[0], y.shape[1]) 
y4 = y + sigma4*np.random.rand(y.shape[0], y.shape[1]) 
print(y1)
# Out:
# [[ 1.22663339  0.07965746  0.11320045  1.8055608   1.13415492 -0.66273985
#   -1.31177283  1.0488376  -1.31168765 -0.07567124  1.2793378   1.17709805
#   -1.05961443  0.9162715   3.09464812  1.28923748  2.14224626  1.05908526
#    2.33468156  0.24246235  1.7352185   0.37319262  1.24039319  0.56425219
#    1.29985269  1.76324511  0.20505809  0.14861406  0.32038047  0.71398086
#    0.77385282  0.96047769  1.19862361  1.08648174  0.00923574  0.99335663
#    0.3595274   2.01233248 -0.70388852  1.36893963  0.62606948  1.91361911
#    0.69075526  0.34685975  0.37270963  1.40384147 -0.71020679  1.36319721
#    0.35825827 -0.58076875]]

# %%
# Apply LS solution on Eq(3.17)
LS1 = np.dot(np.dot(np.linalg.inv(np.dot(X, X.conj().T)), X), y1.conj().T)
LS2 = np.dot(np.dot(np.linalg.inv(np.dot(X, X.conj().T)), X), y2.conj().T)
LS3 = np.dot(np.dot(np.linalg.inv(np.dot(X, X.conj().T)), X), y3.conj().T)
LS4 = np.dot(np.dot(np.linalg.inv(np.dot(X, X.conj().T)), X), y4.conj().T)
print(LS1)
# Out:
# [[ 0.25302182]
#  [-0.22653117]
#  [ 0.52698023]]

# %%
print("If variance equal to 1, the theta 0 is.{}, theta 1 is.{}, and theta 2 is.{}".format(LS1[0], LS1[1], LS1[2]))
# Out:
# If variance equal to 1, the theta 0 is.[0.25302182], theta 1 is.[-0.22653117], and theta 2 is.[0.52698023]

# %%
print("If variance equal to 10, the theta 0 is.{}, theta 1 is.{}, and theta 2 is.{}".format(LS2[0], LS2[1], LS2[2]))
# Out:
# If variance equal to 10, the theta 0 is.[0.25208273], theta 1 is.[-0.19071539], and theta 2 is.[1.44228448]

# %%
print("If variance equal to 10, the theta 0 is.{}, theta 1 is.{}, and theta 2 is.{}".format(LS3[0], LS3[1], LS3[2]))
# Out:
# If variance equal to 10, the theta 0 is.[-0.1168916], theta 1 is.[-0.62042578], and theta 2 is.[8.71410727]

# %%
print("If variance equal to 10, the theta 0 is.{}, theta 1 is.{}, and theta 2 is.{}".format(LS4[0], LS4[1], LS4[2]))
# Out:
# If variance equal to 10, the theta 0 is.[0.02783951], theta 1 is.[-1.66563181], and theta 2 is.[23.93196434]

# %%
df1 = pd.DataFrame(LS1, columns=['var1'])
df2 = pd.DataFrame(LS2, columns=['var10'])
df3 = pd.DataFrame(LS3, columns=['var100'])
df4 = pd.DataFrame(LS4, columns=['var1000'])
df = pd.concat([df1, df2, df3, df4], axis = 1)
df
# Out:
#        var1     var10    var100    var1000
# 0  0.253022  0.252083 -0.116892   0.027840
# 1 -0.226531 -0.190715 -0.620426  -1.665632
# 2  0.526980  1.442284  8.714107  23.931964

# %% [markdown]
# ## Findings
# The larger the variance, the less accurate the $\theta$s. Ideally, we need to reduce the error term.

# %%
features, output, coef = datasets.make_regression(n_samples= 50, n_features=2, n_targets = 1,
                                                  n_informative=10, noise=1, coef = True)

# %%
x = pd.DataFrame(features, columns=['x1', 'x2'])
y = pd.DataFrame(output, columns=['yhat'])
df = pd.DataFrame.join(x, y)
print(df)
# Out:
#           x1        x2        yhat
# 0   0.728431 -1.236926  -51.433233
# 1   0.454408 -0.006540   40.536599
# 2   1.008075 -0.764391   16.741012
# 3  -0.475374  1.000599   52.008385
# 4  -0.451315  2.491183  191.642230
# 5  -0.369126 -2.073758 -226.685171
# 6   0.827559  0.462578  117.142459
# 7  -1.109121  0.371349  -63.340548
# 8  -0.552580 -0.105675  -58.186539
# 9  -1.433095  0.947586  -37.104227
# 10  0.864402  0.761496  149.415049
# 11  0.346714 -0.067936   24.756553
# 12 -1.529050 -1.504063 -276.911908
# 13  0.193775  0.921750  103.986231
# 14  0.902701 -1.716944  -79.399074
# 15 -0.435653  2.119831  159.043336
# 16 -0.795594 -0.851168 -148.537658
# 17  1.330822  1.219831  232.050940
# 18  0.732740  1.389220  194.781185
# 19 -0.326818 -1.357636 -155.904531
# 20  1.711127 -0.815478   73.665100
# 21  0.576540 -0.003219   51.502493
# 22 -2.080619 -1.145907 -291.443600
# 23 -1.753961 -1.100926 -258.951931
# 24  1.246311  0.048891  115.588855
# 25 -0.974249  0.432816  -46.117447
# 26 -0.571034 -1.213516 -162.236286
# 27  0.751546 -0.613113    9.347200
# 28  0.374663  0.498162   78.740571
# 29  0.774374  1.136058  176.357041
# 30  0.447732  0.715754  106.374441
# 31 -0.149807 -0.807581  -88.630092
# 32 -0.336935 -0.008422  -31.914436
# 33 -0.348328 -0.601048  -87.758708
# 34 -1.305661  0.702152  -50.460866
# 35  0.115870  1.182595  120.654225
# 36  0.010399 -0.180845  -17.943803
# 37  1.114086  1.360422  226.022655
# 38 -1.184916  0.571231  -51.466038
# 39  0.426677 -0.087263   29.008133
# 40  0.826136 -0.615014   15.496127
# 41 -0.428880 -0.636744  -98.100862
# 42  1.977934  0.404003  213.849934
# 43 -1.164106 -0.361238 -136.751105
# 44 -0.435690  0.698715   27.441787
# 45  0.019067  2.016031  190.492249
# 46  0.488035  0.247669   67.907751
# 47  0.720031 -0.065614   57.586109
# 48  0.614088  0.455532   97.668094
# 49  0.358721 -0.281084    6.140445
